# %% [markdown]
# ### 0. Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import sequent_peak_algorithm.sequent_peak_algorithm as spa

# %% [markdown]
# ### 1. Create random input data

# %%
np.random.seed = 0
q_in = np.random.rand(100) * 10
q_out = np.random.rand(100) * 10

print("q_in: ", q_in[:5])
print("q_out: ", q_out[:5])
# Out:
# q_in:  [5.9616682  5.64595659 2.91148839 5.16769393 9.50837915]
# q_out:  [4.51113575 2.47599391 6.63172648 2.22273734 2.28890839]

# %% [markdown]
# ### 2. Run sequent peak algorithm and explore results

# %%
res_cap = spa.spa(q_in=q_in, q_out=q_out)

print("Capacity: ", res_cap.capacity)
# Out:
# Capacity:  24.117010234633668

# %% [markdown]
# ### 3. Plot results from sequent peak algorithm

# %%
fig_cap = spa.spa_plot(res_cap)
plt.savefig("example_2_spa.png", dpi=300)

# %% [markdown]
# ### 4. Run storage simulation and explore results

# %%
res_sim = spa.sim(
    q_in=q_in,
    q_out=q_out,
    initial_storage=0.0,
    capacity=res_cap.capacity
)

# %% [markdown]
# ### 5. Plot results from storage simulation

# %%
fig_sim = spa.sim_plot(res_sim)
plt.savefig("example_2_sim.png", dpi=300)
